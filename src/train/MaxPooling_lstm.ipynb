# %%
import tensorflow as tf
import keras
from keras.layers import Input ,Dense, Dropout, Activation, LSTM
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Reshape, BatchNormalization, Add, MaxPooling1D
from keras.models import Sequential
from keras.layers.wrappers import TimeDistributed
from keras.layers.pooling import GlobalAveragePooling2D
from keras.optimizers import Adam, SGD
from keras.utils import np_utils
from keras.models import Model
from keras.optimizers import Adam
from keras.engine.network import Network
from keras import backend as K

import keras.backend.tensorflow_backend as KTF

from keras.initializers import glorot_normal,orthogonal

from keras.callbacks import EarlyStopping,TensorBoard
import csv

from PIL import Image

# %matplotlib inline

import matplotlib.pyplot as plt

import numpy as np
import cv2
import os
import random

from tqdm import tqdm

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.4
# sess = tf.Session(config=config)
# K.set_session(sess)


config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.visible_device_list = "0"
K.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
#どんくらいで学習させるか関連
timesteps=10 #一回のLSTMに入れる値の数
camera=5 #カメラの数

rate = 10 #飛ばすフレーム数（30FPSを30/rateのFPSの動画に疑似変換する．）

#画像関連 
channels=3
img_width=50
img_height=50

#LSTMなどで用いる値
epochs = 100 # エポック数 
batch_size = 5 # バッチサイズ

# %%
class DataLoader:
    def __init__(self, camera_num, file_name, timesteps, width, height):
        self.camera_num = camera_num
        self.file_name =file_name
        self.samples=0
        self.timesteps=timesteps
        self.width=width
        self.height=height
        self.save_numpy()
        
    def save_numpy(self):
        self.samples = int(self.get_sample()/rate)
        if not (os.path.isfile(self.file_name+"train/label_"+str(rate)+".npy")):
            self.make_numpy_learnData()
            self.make_numpy_labelData()
        self.learnData=np.load(self.file_name+"train/learn_"+str(rate)+".npy")
        self.labelData=np.load(self.file_name+"train/label_"+str(rate)+".npy")
    
    def get_sample(self):
        video_path = self.file_name+"video/0.mp4"
        cap = cv2.VideoCapture(video_path)
        num = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        return num
    
    def make_numpy_labelData(self):
        labelData=[[],[],[],[],[]]
        test=[0,0,0,0,0]
        csv_selection=csv.reader(open(self.file_name+"video/mintime_optimize.csv", 'r'))
        for i,row2 in enumerate(csv_selection):
            if(i%rate==0 and i > (self.timesteps-1)*rate-1):
                for j in range(self.camera_num):
                    if j == int(row2[1]):
                        labelData[j].append([1])
                    else:
                        labelData[j].append([0])
                test[int(row2[1])]+=1
        
        
        tmp_list = np.array(labelData)
        tmp_list = tmp_list.astype(np.float)
        np.save(self.file_name+"train/label_"+str(rate)+".npy", tmp_list)
        print(tmp_list.shape)
        print(test)
    
    
    def make_numpy_learnData(self):
        learnData=[]
        for i in range(0, self.camera_num):
            print()
            img_list=[]
            video_path = self.file_name+"video/"+str(i)+".mp4"
            cap = cv2.VideoCapture(video_path)
            video_len = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            for j in range(0,video_len):
                
                pro_size=20
                bar = int(j*pro_size/video_len)
                pro_bar = ('=' * bar) + (' ' * (pro_size - bar))
                percent ='{:03f}'.format(j / video_len * 100.)
                print('\r{0}/{1} [{2}] {3}%'.format((i+1), self.camera_num, pro_bar, percent), end='')
                
                ret, frame = cap.read()
                if(j%rate==0):
                    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    img=Image.fromarray(frame)
                    img = img.resize((self.width, self.height))
                    x = np.array(img, dtype=np.float32)
                    x = x / 255.
                    img_list.append(x)
            learnData.append(img_list)
            
        tmp_list=np.array(learnData)
        tmp_list=tmp_list.astype(np.float)
        np.save(self.file_name+"train/learn_"+str(rate)+".npy", tmp_list)
        print(tmp_list.shape)


    def make_learndata(self):
        data_name=self.file_name+"train/learn_0_"+str(rate)+".npy"
        if (os.path.isfile(data_name)):
            test=np.load(data_name)
        else:
            all_list = [np.empty((0,self.timesteps, self.width, self.height, 3), np.float)]*self.camera_num
            tmp_list = [np.empty((0,self.timesteps, self.width, self.height, 3), np.float)]*self.camera_num
            for i in range(0, self.labelData.shape[1]):
                #まずはすべての分だけ回す
                pro_size=20
                bar = int(i*pro_size/self.labelData.shape[1])
                pro_bar = ('=' * bar) + (' ' * (pro_size - bar))
                percent ='{:03f}'.format(i / self.labelData.shape[1] * 100.)
                print('\r [{0}] {1}%'.format(pro_bar, percent), end='')

                for camera in range(0, self.camera_num):
                    #カメラの台数だけ回す
                    #tmp_list[camera]の同じ引数（番号）には同じ時間軸のsequenceが入っている．
                    first_list =np.empty((0, self.width, self.height, 3), np.float)
                    for l in range(0, self.timesteps):
                        #timesteps分のndarrayを作る．
                        img=self.learnData[camera,i+l]
                        first_list =np.append(first_list, [img], axis=0)
                    #あるカメラについて，１つのsequenceがfirst_listに出来上がっている状態．
                    tmp_list[camera]=np.append(tmp_list[camera], [first_list], axis=0)


                if(tmp_list[0].shape[0]>100 or i == self.labelData.shape[1]-1):
                    #処理時間短縮のため，sequenceがtmp_listに溜まってきたら，全体に統合してまたtmp_listを初期化する．
                    for camera in range(0, self.camera_num):
                        all_list[camera]=np.append(all_list[camera], tmp_list[camera], axis=0)
                        tmp_list[camera] = np.empty((0,self.timesteps, self.width, self.height, 3), np.float)
            
            for camera in range(0, self.camera_num):
                data_name=self.file_name+"train/learn_"+str(camera)+"_"+str(rate)
                np.save(data_name, all_list[camera])
    
    
    def make_labeldata(self):
        data_name=self.file_name+"train/final_label_"+str(rate)+"_.npy"
        if (os.path.isfile(data_name)):
            test=np.load(data_name)
        else:
            np.save(data_name, self.labelData)
    
    
    def get_learndata(self, num):
        data_name=self.file_name+"train/learn_"+str(num)+"_"+str(rate)+".npy"
        test=np.load(data_name)
        return test
    
    
    def get_labeldata(self):
        data_name=self.file_name+"train/final_label_"+str(rate)+"_.npy"
        test=np.load(data_name)
        return test
    
    
    def show(self):
        print(0,self.get_learndata(0).shape)
        print(1,self.get_learndata(1).shape)
        print(2,self.get_learndata(2).shape)
        print(3,self.get_learndata(3).shape)
        print(4,self.get_learndata(4).shape)
        print(self.get_labeldata().shape)

# %%
data = DataLoader(camera, "./data/20190423-0128/", timesteps, img_width, img_height)
# Out:
# 1/5 [=================== ] 99.998154%
# 2/5 [=================== ] 99.998154%
# 3/5 [=================== ] 99.998154%
# 4/5 [=================== ] 99.998154%
# 5/5 [=================== ] 99.998154%(5, 5418, 50, 50, 3)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-548b7309e6eb> in <module>
# ----> 1 data = DataLoader(camera, "./data/20190423-0128/", timesteps, img_width, img_height)
#
# <ipython-input-5-8683f110a503> in __init__(self, camera_num, file_name, timesteps, width, height)
#       7         self.width=width
#       8         self.height=height
# ----> 9         self.save_numpy()
#      10
#      11     def save_numpy(self):
#
# <ipython-input-5-8683f110a503> in save_numpy(self)
#      13         if not (os.path.isfile(self.file_name+"train/label_"+str(rate)+".npy")):
#      14             self.make_numpy_learnData()
# ---> 15             self.make_numpy_labelData()
#      16         self.learnData=np.load(self.file_name+"train/learn_"+str(rate)+".npy")
#      17         self.labelData=np.load(self.file_name+"train/label_"+str(rate)+".npy")
#
# <ipython-input-5-8683f110a503> in make_numpy_labelData(self)
#      26         labelData=[[],[],[],[],[]]
#      27         test=[0,0,0,0,0]
# ---> 28         csv_selection=csv.reader(open(self.file_name+"video/mintime_optimize.csv", 'r'))
#      29         for i,row2 in enumerate(csv_selection):
#      30             if(i%rate==0 and i > (self.timesteps-1)*rate-1):
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/20190423-0128/video/mintime_optimize.csv'

# %%
data.make_learndata()
data.make_labeldata()
data.show()

# %%
class Resnet18 :
    ##
    ##　Resnet-18の作成
    ##
    def __init__(self, width, height, channels):
        self.img_rows=height
        self.img_cols=width
        self.img_channels=channels
    
    def rescell(self, data, filters, kernel_size, option=False):
        strides=(1,1)
        if option:
            strides=(2,2)
        x=Convolution2D(filters=filters,kernel_size=kernel_size,strides=strides,padding="same")(data)
        x=BatchNormalization()(x)
        x=Activation('relu')(x)
        
        data=Convolution2D(filters=int(x.shape[3]), kernel_size=(1,1), strides=strides, padding="same")(data)
        x=Convolution2D(filters=filters,kernel_size=kernel_size,strides=(1,1),padding="same")(x)
        x=BatchNormalization()(x)
        x=Add()([x,data])
        x=Activation('relu')(x)
        
        return x
    
    def create_resnet18(self):
        inputs=Input(shape=(self.img_rows, self.img_cols, self.img_channels))
        x=Convolution2D(64,(7,7), padding="same", input_shape=(self.img_rows, self.img_cols),activation="relu")(inputs)
        x=MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(x)

        x=self.rescell(x,64,(3,3))
        x=self.rescell(x,64,(3,3))
        x=self.rescell(x,64,(3,3))
        
        x=self.rescell(x,128,(3,3),True)
        x=self.rescell(x,128,(3,3))

        x=self.rescell(x,256,(3,3),True)
        x=self.rescell(x,256,(3,3))
        
        x=self.rescell(x,512,(3,3),True)
        x=self.rescell(x,512,(3,3))
        
        model=Model(inputs=inputs,outputs=[x])
        return model

    def get_resnet18(self):
        return self.create_resnet18()

# %%
class Prediction :
    def __init__(self, timesteps, n_out, width, height):
        self.maxlen = timesteps
        self.n_out = n_out
        self.width=width
        self.height=height
        self.resnet = Resnet18(width, height, 3).get_resnet18()
        self.sharedLSTMmodel = self.create_sharedLSTMmodel()
        self.sharedRateModel = self.create_sharedRatemodel()
    
    
    def create_sharedLSTMmodel(self):
        inputs = Input(shape=(self.maxlen, self.height, self.width, 3))
        
        x = TimeDistributed(self.resnet,name="resnet")(inputs)
        x = TimeDistributed(GlobalAveragePooling2D(), name="GAP")(x)
        x = TimeDistributed(Dense(512,activation='relu'), name="dense")(x)
        predictions = LSTM(256, batch_input_shape = (None, self.maxlen, 512),
             kernel_initializer = glorot_normal(seed=20181020),
             recurrent_initializer = orthogonal(gain=1.0, seed=20181020), 
             dropout = 0.01, 
             recurrent_dropout = 0.01)(x)
        
        predictions =Reshape((1,256))(predictions)
        shared_layers = Model(inputs, predictions, name="shared_LSTMlayers")
        return shared_layers
    
    
    def create_sharedRatemodel(self):
        inputs = Input(shape=(512,))
        mid_dense = Dense(256, activation='relu')(inputs)
        predictions = Dense(1, activation='sigmoid')(mid_dense)
        shared_layers = Model(inputs, predictions, name="shared_Ratelayers")
        return shared_layers


    def create_model(self):
        model_input1 = Input(shape=(self.maxlen, self.height, self.width, 3))
        model_input2 = Input(shape=(self.maxlen, self.height, self.width, 3))
        model_input3 = Input(shape=(self.maxlen, self.height, self.width, 3))
        model_input4 = Input(shape=(self.maxlen, self.height, self.width, 3))
        model_input5 = Input(shape=(self.maxlen, self.height, self.width, 3))
        
        mid_feature1 = self.sharedLSTMmodel(model_input1)
        mid_feature2 = self.sharedLSTMmodel(model_input2)
        mid_feature3 = self.sharedLSTMmodel(model_input3)
        mid_feature4 = self.sharedLSTMmodel(model_input4)
        mid_feature5 = self.sharedLSTMmodel(model_input5)
        
        
        pooling_vector = keras.layers.concatenate([mid_feature1, mid_feature2, mid_feature3, mid_feature4, mid_feature5], axis=1)
        pooling_vector = MaxPooling1D(pool_size=camera)(pooling_vector)
        
        
        merge_feature1 = keras.layers.concatenate([mid_feature1, pooling_vector], axis=-1)
        merge_feature2 = keras.layers.concatenate([mid_feature2, pooling_vector], axis=-1)
        merge_feature3 = keras.layers.concatenate([mid_feature3, pooling_vector], axis=-1)
        merge_feature4 = keras.layers.concatenate([mid_feature4, pooling_vector], axis=-1)
        merge_feature5 = keras.layers.concatenate([mid_feature5, pooling_vector], axis=-1)
        
        merge_feature1 = Reshape((512,))(merge_feature1)
        merge_feature2 = Reshape((512,))(merge_feature2)
        merge_feature3 = Reshape((512,))(merge_feature3)
        merge_feature4 = Reshape((512,))(merge_feature4)
        merge_feature5 = Reshape((512,))(merge_feature5)
        
        predictions1 = self.sharedRateModel(merge_feature1)
        predictions2 = self.sharedRateModel(merge_feature2)
        predictions3 = self.sharedRateModel(merge_feature3)
        predictions4 = self.sharedRateModel(merge_feature4)
        predictions5 = self.sharedRateModel(merge_feature5)
        
        model = Model(inputs=[model_input1, model_input2, model_input3, model_input4, model_input5], 
                      outputs=[predictions1,predictions2,predictions3,predictions4,predictions5])
        model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
        return model
    
    
    def train(self, x_train, t_train, x_vali, t_vali, batch_size, epochs):
        early_stopping = EarlyStopping(patience=20, verbose=1)
        model = self.create_model()
        hist = model.fit(x=[x_train[0], x_train[1], x_train[2], x_train[3], x_train[4]], y=t_train, batch_size = batch_size,
                         epochs = epochs, validation_data=([x_vali[0], x_vali[1], x_vali[2], x_vali[3], x_vali[4]], t_vali),
                         callbacks = [early_stopping])
        return model, hist
    
    
    def train_keras(self, x_train, t_train, batch_size, epochs):
        early_stopping = EarlyStopping(patience=20, verbose=1)
        model = self.create_model()
        hist = model.fit([x_train[0], x_train[1], x_train[2], x_train[3], x_train[4]], 
                         [t_train[0], t_train[1], t_train[2], t_train[3], t_train[4]],
                         batch_size = batch_size, epochs = epochs, verbose = 1,
                         callbacks = [early_stopping], validation_split = 0.2,
                         class_weight={0:1,1:4})
        return model, hist

# %%
# モデル定義
pred = Prediction(timesteps, camera, img_width, img_height)
model = pred.create_model()
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_65 (InputLayer)           (None, 10, 50, 50, 3 0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           (None, 10, 50, 50, 3 0
# __________________________________________________________________________________________________
# input_67 (InputLayer)           (None, 10, 50, 50, 3 0
# __________________________________________________________________________________________________
# input_68 (InputLayer)           (None, 10, 50, 50, 3 0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           (None, 10, 50, 50, 3 0
# __________________________________________________________________________________________________
# shared_LSTMlayers (Model)       (None, 1, 256)       12668992    input_65[0][0]
#                                                                  input_66[0][0]
#                                                                  input_67[0][0]
#                                                                  input_68[0][0]
#                                                                  input_69[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 5, 256)       0           shared_LSTMlayers[1][0]
#                                                                  shared_LSTMlayers[2][0]
#                                                                  shared_LSTMlayers[3][0]
#                                                                  shared_LSTMlayers[4][0]
#                                                                  shared_LSTMlayers[5][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 1, 256)       0           concatenate_49[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 1, 512)       0           shared_LSTMlayers[1][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 1, 512)       0           shared_LSTMlayers[2][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 1, 512)       0           shared_LSTMlayers[3][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 1, 512)       0           shared_LSTMlayers[4][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 1, 512)       0           shared_LSTMlayers[5][0]
#                                                                  max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# reshape_49 (Reshape)            (None, 512)          0           concatenate_50[0][0]
# __________________________________________________________________________________________________
# reshape_50 (Reshape)            (None, 512)          0           concatenate_51[0][0]
# __________________________________________________________________________________________________
# reshape_51 (Reshape)            (None, 512)          0           concatenate_52[0][0]
# __________________________________________________________________________________________________
# reshape_52 (Reshape)            (None, 512)          0           concatenate_53[0][0]
# __________________________________________________________________________________________________
# reshape_53 (Reshape)            (None, 512)          0           concatenate_54[0][0]
# __________________________________________________________________________________________________
# shared_Ratelayers (Model)       (None, 1)            131585      reshape_49[0][0]
#                                                                  reshape_50[0][0]
#                                                                  reshape_51[0][0]
#                                                                  reshape_52[0][0]
#                                                                  reshape_53[0][0]
# ==================================================================================================
# Total params: 12,800,577
# Trainable params: 12,792,641
# Non-trainable params: 7,936
# __________________________________________________________________________________________________
# None

# %%
from tqdm import tqdm
train_learn=[np.empty((data.get_labeldata().shape[0],10, 50, 50, 3), np.float)]*camera
vali_learn=[np.empty((0,10, 50, 50, 3), np.float)]*camera
train_label=data.get_labeldata()
vali_label=np.empty((0,camera), np.float)

print(train_label.shape)

for j in range(0,camera):
    train_learn[j]=data.get_learndata(j)

# for i in tqdm(range(0,int(0.1*test_label.shape[0]))):
#     random_angle = int(random.randint(0,test_label.shape[0]-1))
#     for j in range(0,camera):
#         vali_learn[j]=np.append(vali_learn[j], [test_learn[j][random_angle]],axis=0)
#         test_learn[j]=np.delete(test_learn[j], random_angle,0)
#     vali_label=np.append(vali_label, [test_label[random_angle]], axis=0)
#     test_label=np.delete(test_label, random_angle,0)
# Out:
# (5, 1611, 1)

# %%
# 学習
#model , hist = pred.train(test_learn, test_label, vali_learn, vali_label, batch_size, epochs)
model , hist = pred.train_keras(train_learn, train_label, batch_size, epochs)
# テスト
#score = model.evaluate(test_learn, test_label, batch_size = batch_size, verbose = 1)
#print("score:", score)
# Out:
# Train on 1288 samples, validate on 323 samples
# Epoch 1/100
# 1288/1288 [==============================] - 123s 95ms/step - loss: 2.4163 - shared_Ratelayers_loss: 0.9131 - shared_Ratelayers_acc: 0.8020 - shared_Ratelayers_acc_1: 0.9589 - shared_Ratelayers_acc_2: 0.9325 - shared_Ratelayers_acc_3: 0.8269 - shared_Ratelayers_acc_4: 0.4783 - val_loss: 2.4712 - val_shared_Ratelayers_loss: 1.6487 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.0991
# Epoch 2/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 2.2978 - shared_Ratelayers_loss: 0.8610 - shared_Ratelayers_acc: 0.8051 - shared_Ratelayers_acc_1: 0.9581 - shared_Ratelayers_acc_2: 0.9309 - shared_Ratelayers_acc_3: 0.8269 - shared_Ratelayers_acc_4: 0.4744 - val_loss: 2.2764 - val_shared_Ratelayers_loss: 1.4989 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.0991
# Epoch 3/100
# 1288/1288 [==============================] - 74s 58ms/step - loss: 2.2327 - shared_Ratelayers_loss: 0.8085 - shared_Ratelayers_acc: 0.8144 - shared_Ratelayers_acc_1: 0.9511 - shared_Ratelayers_acc_2: 0.9278 - shared_Ratelayers_acc_3: 0.8144 - shared_Ratelayers_acc_4: 0.5000 - val_loss: 2.3012 - val_shared_Ratelayers_loss: 1.5929 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.0991
# Epoch 4/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 2.1171 - shared_Ratelayers_loss: 0.7570 - shared_Ratelayers_acc: 0.8113 - shared_Ratelayers_acc_1: 0.9573 - shared_Ratelayers_acc_2: 0.9208 - shared_Ratelayers_acc_3: 0.8144 - shared_Ratelayers_acc_4: 0.5334 - val_loss: 2.3697 - val_shared_Ratelayers_loss: 1.1127 - val_shared_Ratelayers_acc: 0.9598 - val_shared_Ratelayers_acc_1: 0.9598 - val_shared_Ratelayers_acc_2: 0.9598 - val_shared_Ratelayers_acc_3: 0.5604 - val_shared_Ratelayers_acc_4: 0.3963
# Epoch 5/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 2.0368 - shared_Ratelayers_loss: 0.7222 - shared_Ratelayers_acc: 0.8253 - shared_Ratelayers_acc_1: 0.9488 - shared_Ratelayers_acc_2: 0.9169 - shared_Ratelayers_acc_3: 0.7997 - shared_Ratelayers_acc_4: 0.5707 - val_loss: 2.4101 - val_shared_Ratelayers_loss: 1.0752 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.0991
# Epoch 6/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 2.0903 - shared_Ratelayers_loss: 0.7622 - shared_Ratelayers_acc: 0.8160 - shared_Ratelayers_acc_1: 0.9526 - shared_Ratelayers_acc_2: 0.9317 - shared_Ratelayers_acc_3: 0.8199 - shared_Ratelayers_acc_4: 0.4953 - val_loss: 2.0230 - val_shared_Ratelayers_loss: 0.9053 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9907 - val_shared_Ratelayers_acc_4: 0.1269
# Epoch 7/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 2.1583 - shared_Ratelayers_loss: 0.7768 - shared_Ratelayers_acc: 0.8183 - shared_Ratelayers_acc_1: 0.9565 - shared_Ratelayers_acc_2: 0.9293 - shared_Ratelayers_acc_3: 0.8175 - shared_Ratelayers_acc_4: 0.5264 - val_loss: 2.3367 - val_shared_Ratelayers_loss: 1.1421 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9598 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.2105
# Epoch 8/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 1.9597 - shared_Ratelayers_loss: 0.6695 - shared_Ratelayers_acc: 0.8385 - shared_Ratelayers_acc_1: 0.9519 - shared_Ratelayers_acc_2: 0.9340 - shared_Ratelayers_acc_3: 0.8168 - shared_Ratelayers_acc_4: 0.6180 - val_loss: 2.0312 - val_shared_Ratelayers_loss: 1.0077 - val_shared_Ratelayers_acc: 0.9628 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.1238
# Epoch 9/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.9666 - shared_Ratelayers_loss: 0.6701 - shared_Ratelayers_acc: 0.8253 - shared_Ratelayers_acc_1: 0.9526 - shared_Ratelayers_acc_2: 0.9340 - shared_Ratelayers_acc_3: 0.8121 - shared_Ratelayers_acc_4: 0.6258 - val_loss: 2.1883 - val_shared_Ratelayers_loss: 1.0066 - val_shared_Ratelayers_acc: 0.9598 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9598 - val_shared_Ratelayers_acc_4: 0.1053
# Epoch 10/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.7994 - shared_Ratelayers_loss: 0.6153 - shared_Ratelayers_acc: 0.8455 - shared_Ratelayers_acc_1: 0.9573 - shared_Ratelayers_acc_2: 0.9325 - shared_Ratelayers_acc_3: 0.8059 - shared_Ratelayers_acc_4: 0.6460 - val_loss: 1.7879 - val_shared_Ratelayers_loss: 0.6865 - val_shared_Ratelayers_acc: 0.9071 - val_shared_Ratelayers_acc_1: 0.9659 - val_shared_Ratelayers_acc_2: 0.9598 - val_shared_Ratelayers_acc_3: 0.9938 - val_shared_Ratelayers_acc_4: 0.5759
# Epoch 11/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.8096 - shared_Ratelayers_loss: 0.6061 - shared_Ratelayers_acc: 0.8346 - shared_Ratelayers_acc_1: 0.9589 - shared_Ratelayers_acc_2: 0.9371 - shared_Ratelayers_acc_3: 0.8144 - shared_Ratelayers_acc_4: 0.6661 - val_loss: 1.9850 - val_shared_Ratelayers_loss: 0.9872 - val_shared_Ratelayers_acc: 0.9412 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9567 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.5201
# Epoch 12/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 1.7545 - shared_Ratelayers_loss: 0.6137 - shared_Ratelayers_acc: 0.8494 - shared_Ratelayers_acc_1: 0.9604 - shared_Ratelayers_acc_2: 0.9402 - shared_Ratelayers_acc_3: 0.8090 - shared_Ratelayers_acc_4: 0.6669 - val_loss: 1.4300 - val_shared_Ratelayers_loss: 0.6960 - val_shared_Ratelayers_acc: 0.9040 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9845 - val_shared_Ratelayers_acc_4: 0.6811
# Epoch 13/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.7715 - shared_Ratelayers_loss: 0.6148 - shared_Ratelayers_acc: 0.8424 - shared_Ratelayers_acc_1: 0.9627 - shared_Ratelayers_acc_2: 0.9348 - shared_Ratelayers_acc_3: 0.8129 - shared_Ratelayers_acc_4: 0.6592 - val_loss: 2.8520 - val_shared_Ratelayers_loss: 0.7456 - val_shared_Ratelayers_acc: 0.8019 - val_shared_Ratelayers_acc_1: 0.9412 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.8854 - val_shared_Ratelayers_acc_4: 0.5201
# Epoch 14/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 1.7505 - shared_Ratelayers_loss: 0.6169 - shared_Ratelayers_acc: 0.8478 - shared_Ratelayers_acc_1: 0.9589 - shared_Ratelayers_acc_2: 0.9410 - shared_Ratelayers_acc_3: 0.8075 - shared_Ratelayers_acc_4: 0.6661 - val_loss: 1.4112 - val_shared_Ratelayers_loss: 0.6941 - val_shared_Ratelayers_acc: 0.8947 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9845 - val_shared_Ratelayers_acc_4: 0.6471
# Epoch 15/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.5695 - shared_Ratelayers_loss: 0.5584 - shared_Ratelayers_acc: 0.8773 - shared_Ratelayers_acc_1: 0.9643 - shared_Ratelayers_acc_2: 0.9441 - shared_Ratelayers_acc_3: 0.8043 - shared_Ratelayers_acc_4: 0.6980 - val_loss: 1.5752 - val_shared_Ratelayers_loss: 0.9735 - val_shared_Ratelayers_acc: 0.9505 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.5325
# Epoch 16/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.5541 - shared_Ratelayers_loss: 0.5530 - shared_Ratelayers_acc: 0.8727 - shared_Ratelayers_acc_1: 0.9612 - shared_Ratelayers_acc_2: 0.9418 - shared_Ratelayers_acc_3: 0.8175 - shared_Ratelayers_acc_4: 0.7073 - val_loss: 1.7249 - val_shared_Ratelayers_loss: 0.8896 - val_shared_Ratelayers_acc: 0.9598 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.4427
# Epoch 17/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.4595 - shared_Ratelayers_loss: 0.5350 - shared_Ratelayers_acc: 0.8797 - shared_Ratelayers_acc_1: 0.9635 - shared_Ratelayers_acc_2: 0.9425 - shared_Ratelayers_acc_3: 0.8175 - shared_Ratelayers_acc_4: 0.7011 - val_loss: 1.7508 - val_shared_Ratelayers_loss: 0.9145 - val_shared_Ratelayers_acc: 0.8514 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9319 - val_shared_Ratelayers_acc_3: 0.9381 - val_shared_Ratelayers_acc_4: 0.3684
# Epoch 18/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.4726 - shared_Ratelayers_loss: 0.5392 - shared_Ratelayers_acc: 0.8882 - shared_Ratelayers_acc_1: 0.9666 - shared_Ratelayers_acc_2: 0.9371 - shared_Ratelayers_acc_3: 0.8230 - shared_Ratelayers_acc_4: 0.6964 - val_loss: 1.7888 - val_shared_Ratelayers_loss: 0.8976 - val_shared_Ratelayers_acc: 0.8545 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9505 - val_shared_Ratelayers_acc_4: 0.5820
# Epoch 19/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 1.3759 - shared_Ratelayers_loss: 0.5231 - shared_Ratelayers_acc: 0.8820 - shared_Ratelayers_acc_1: 0.9759 - shared_Ratelayers_acc_2: 0.9387 - shared_Ratelayers_acc_3: 0.8292 - shared_Ratelayers_acc_4: 0.7197 - val_loss: 1.0844 - val_shared_Ratelayers_loss: 0.4532 - val_shared_Ratelayers_acc: 0.9164 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9938 - val_shared_Ratelayers_acc_4: 0.7554
# Epoch 20/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.3738 - shared_Ratelayers_loss: 0.5096 - shared_Ratelayers_acc: 0.8898 - shared_Ratelayers_acc_1: 0.9752 - shared_Ratelayers_acc_2: 0.9394 - shared_Ratelayers_acc_3: 0.8214 - shared_Ratelayers_acc_4: 0.7205 - val_loss: 2.3182 - val_shared_Ratelayers_loss: 1.6119 - val_shared_Ratelayers_acc: 0.8824 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9845 - val_shared_Ratelayers_acc_4: 0.1146
# Epoch 21/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.2680 - shared_Ratelayers_loss: 0.4907 - shared_Ratelayers_acc: 0.9006 - shared_Ratelayers_acc_1: 0.9775 - shared_Ratelayers_acc_2: 0.9425 - shared_Ratelayers_acc_3: 0.8362 - shared_Ratelayers_acc_4: 0.7384 - val_loss: 1.1991 - val_shared_Ratelayers_loss: 0.4723 - val_shared_Ratelayers_acc: 0.9040 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9628 - val_shared_Ratelayers_acc_3: 0.9659 - val_shared_Ratelayers_acc_4: 0.8235
# Epoch 22/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.2619 - shared_Ratelayers_loss: 0.4736 - shared_Ratelayers_acc: 0.9022 - shared_Ratelayers_acc_1: 0.9736 - shared_Ratelayers_acc_2: 0.9387 - shared_Ratelayers_acc_3: 0.8370 - shared_Ratelayers_acc_4: 0.7570 - val_loss: 1.2511 - val_shared_Ratelayers_loss: 0.5464 - val_shared_Ratelayers_acc: 0.8638 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9659 - val_shared_Ratelayers_acc_4: 0.8142
# Epoch 23/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 1.2646 - shared_Ratelayers_loss: 0.4872 - shared_Ratelayers_acc: 0.8975 - shared_Ratelayers_acc_1: 0.9783 - shared_Ratelayers_acc_2: 0.9488 - shared_Ratelayers_acc_3: 0.8362 - shared_Ratelayers_acc_4: 0.7360 - val_loss: 1.4887 - val_shared_Ratelayers_loss: 0.8662 - val_shared_Ratelayers_acc: 0.8824 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9783 - val_shared_Ratelayers_acc_4: 0.5944
# Epoch 24/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.1641 - shared_Ratelayers_loss: 0.4541 - shared_Ratelayers_acc: 0.8991 - shared_Ratelayers_acc_1: 0.9767 - shared_Ratelayers_acc_2: 0.9441 - shared_Ratelayers_acc_3: 0.8408 - shared_Ratelayers_acc_4: 0.7484 - val_loss: 1.2343 - val_shared_Ratelayers_loss: 0.5302 - val_shared_Ratelayers_acc: 0.8576 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9350 - val_shared_Ratelayers_acc_3: 0.9443 - val_shared_Ratelayers_acc_4: 0.7740
# Epoch 25/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.1591 - shared_Ratelayers_loss: 0.4534 - shared_Ratelayers_acc: 0.9154 - shared_Ratelayers_acc_1: 0.9775 - shared_Ratelayers_acc_2: 0.9480 - shared_Ratelayers_acc_3: 0.8393 - shared_Ratelayers_acc_4: 0.7741 - val_loss: 1.3431 - val_shared_Ratelayers_loss: 0.6525 - val_shared_Ratelayers_acc: 0.8793 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9628 - val_shared_Ratelayers_acc_3: 0.9412 - val_shared_Ratelayers_acc_4: 0.6811
# Epoch 26/100
# 1288/1288 [==============================] - 74s 58ms/step - loss: 1.1516 - shared_Ratelayers_loss: 0.4601 - shared_Ratelayers_acc: 0.9123 - shared_Ratelayers_acc_1: 0.9790 - shared_Ratelayers_acc_2: 0.9441 - shared_Ratelayers_acc_3: 0.8525 - shared_Ratelayers_acc_4: 0.7609 - val_loss: 1.3711 - val_shared_Ratelayers_loss: 0.6377 - val_shared_Ratelayers_acc: 0.9288 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9845 - val_shared_Ratelayers_acc_4: 0.6223
# Epoch 27/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.0816 - shared_Ratelayers_loss: 0.4339 - shared_Ratelayers_acc: 0.9247 - shared_Ratelayers_acc_1: 0.9744 - shared_Ratelayers_acc_2: 0.9596 - shared_Ratelayers_acc_3: 0.8276 - shared_Ratelayers_acc_4: 0.7811 - val_loss: 1.4758 - val_shared_Ratelayers_loss: 0.5536 - val_shared_Ratelayers_acc: 0.8452 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9288 - val_shared_Ratelayers_acc_3: 0.9164 - val_shared_Ratelayers_acc_4: 0.7399
# Epoch 28/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 1.0656 - shared_Ratelayers_loss: 0.4305 - shared_Ratelayers_acc: 0.9185 - shared_Ratelayers_acc_1: 0.9798 - shared_Ratelayers_acc_2: 0.9511 - shared_Ratelayers_acc_3: 0.8486 - shared_Ratelayers_acc_4: 0.7717 - val_loss: 1.2843 - val_shared_Ratelayers_loss: 0.5684 - val_shared_Ratelayers_acc: 0.8638 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9288 - val_shared_Ratelayers_acc_4: 0.7461
# Epoch 29/100
# 1288/1288 [==============================] - 73s 56ms/step - loss: 1.0176 - shared_Ratelayers_loss: 0.4185 - shared_Ratelayers_acc: 0.9224 - shared_Ratelayers_acc_1: 0.9829 - shared_Ratelayers_acc_2: 0.9550 - shared_Ratelayers_acc_3: 0.8533 - shared_Ratelayers_acc_4: 0.7826 - val_loss: 2.4257 - val_shared_Ratelayers_loss: 1.3783 - val_shared_Ratelayers_acc: 0.8885 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9876 - val_shared_Ratelayers_acc_4: 0.1455
# Epoch 30/100
# 1288/1288 [==============================] - 73s 57ms/step - loss: 0.9909 - shared_Ratelayers_loss: 0.4124 - shared_Ratelayers_acc: 0.9123 - shared_Ratelayers_acc_1: 0.9821 - shared_Ratelayers_acc_2: 0.9612 - shared_Ratelayers_acc_3: 0.8463 - shared_Ratelayers_acc_4: 0.7904 - val_loss: 2.2764 - val_shared_Ratelayers_loss: 1.2069 - val_shared_Ratelayers_acc: 0.9071 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 1.0000 - val_shared_Ratelayers_acc_4: 0.1455
# Epoch 31/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.9534 - shared_Ratelayers_loss: 0.4097 - shared_Ratelayers_acc: 0.9301 - shared_Ratelayers_acc_1: 0.9829 - shared_Ratelayers_acc_2: 0.9589 - shared_Ratelayers_acc_3: 0.8540 - shared_Ratelayers_acc_4: 0.7834 - val_loss: 1.4838 - val_shared_Ratelayers_loss: 0.5783 - val_shared_Ratelayers_acc: 0.8916 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9628 - val_shared_Ratelayers_acc_3: 0.9102 - val_shared_Ratelayers_acc_4: 0.7307
# Epoch 32/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.9321 - shared_Ratelayers_loss: 0.3831 - shared_Ratelayers_acc: 0.9325 - shared_Ratelayers_acc_1: 0.9821 - shared_Ratelayers_acc_2: 0.9682 - shared_Ratelayers_acc_3: 0.8587 - shared_Ratelayers_acc_4: 0.8075 - val_loss: 1.2168 - val_shared_Ratelayers_loss: 0.5814 - val_shared_Ratelayers_acc: 0.9009 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.9659 - val_shared_Ratelayers_acc_3: 0.9721 - val_shared_Ratelayers_acc_4: 0.6811
# Epoch 33/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.8523 - shared_Ratelayers_loss: 0.3494 - shared_Ratelayers_acc: 0.9433 - shared_Ratelayers_acc_1: 0.9891 - shared_Ratelayers_acc_2: 0.9627 - shared_Ratelayers_acc_3: 0.8719 - shared_Ratelayers_acc_4: 0.8315 - val_loss: 2.1580 - val_shared_Ratelayers_loss: 1.2082 - val_shared_Ratelayers_acc: 0.8700 - val_shared_Ratelayers_acc_1: 0.9567 - val_shared_Ratelayers_acc_2: 0.9009 - val_shared_Ratelayers_acc_3: 0.9164 - val_shared_Ratelayers_acc_4: 0.6687
# Epoch 34/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.8392 - shared_Ratelayers_loss: 0.3550 - shared_Ratelayers_acc: 0.9394 - shared_Ratelayers_acc_1: 0.9891 - shared_Ratelayers_acc_2: 0.9689 - shared_Ratelayers_acc_3: 0.8773 - shared_Ratelayers_acc_4: 0.8121 - val_loss: 2.1020 - val_shared_Ratelayers_loss: 1.0946 - val_shared_Ratelayers_acc: 0.8297 - val_shared_Ratelayers_acc_1: 0.9381 - val_shared_Ratelayers_acc_2: 0.9567 - val_shared_Ratelayers_acc_3: 0.8390 - val_shared_Ratelayers_acc_4: 0.6966
# Epoch 35/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.8237 - shared_Ratelayers_loss: 0.3408 - shared_Ratelayers_acc: 0.9371 - shared_Ratelayers_acc_1: 0.9907 - shared_Ratelayers_acc_2: 0.9635 - shared_Ratelayers_acc_3: 0.8610 - shared_Ratelayers_acc_4: 0.8199 - val_loss: 1.8207 - val_shared_Ratelayers_loss: 1.0285 - val_shared_Ratelayers_acc: 0.8947 - val_shared_Ratelayers_acc_1: 0.9659 - val_shared_Ratelayers_acc_2: 0.9226 - val_shared_Ratelayers_acc_3: 0.9288 - val_shared_Ratelayers_acc_4: 0.5759
# Epoch 36/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.7841 - shared_Ratelayers_loss: 0.3365 - shared_Ratelayers_acc: 0.9542 - shared_Ratelayers_acc_1: 0.9922 - shared_Ratelayers_acc_2: 0.9736 - shared_Ratelayers_acc_3: 0.8742 - shared_Ratelayers_acc_4: 0.8168 - val_loss: 2.0244 - val_shared_Ratelayers_loss: 1.1233 - val_shared_Ratelayers_acc: 0.8576 - val_shared_Ratelayers_acc_1: 0.9257 - val_shared_Ratelayers_acc_2: 0.9412 - val_shared_Ratelayers_acc_3: 0.8947 - val_shared_Ratelayers_acc_4: 0.7337
# Epoch 37/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.7856 - shared_Ratelayers_loss: 0.3232 - shared_Ratelayers_acc: 0.9410 - shared_Ratelayers_acc_1: 0.9930 - shared_Ratelayers_acc_2: 0.9682 - shared_Ratelayers_acc_3: 0.8727 - shared_Ratelayers_acc_4: 0.8385 - val_loss: 1.7199 - val_shared_Ratelayers_loss: 0.8502 - val_shared_Ratelayers_acc: 0.8978 - val_shared_Ratelayers_acc_1: 0.9659 - val_shared_Ratelayers_acc_2: 0.8824 - val_shared_Ratelayers_acc_3: 0.9133 - val_shared_Ratelayers_acc_4: 0.7616
# Epoch 38/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.7471 - shared_Ratelayers_loss: 0.3169 - shared_Ratelayers_acc: 0.9534 - shared_Ratelayers_acc_1: 0.9922 - shared_Ratelayers_acc_2: 0.9697 - shared_Ratelayers_acc_3: 0.8758 - shared_Ratelayers_acc_4: 0.8432 - val_loss: 1.6323 - val_shared_Ratelayers_loss: 0.7383 - val_shared_Ratelayers_acc: 0.8545 - val_shared_Ratelayers_acc_1: 0.9628 - val_shared_Ratelayers_acc_2: 0.9133 - val_shared_Ratelayers_acc_3: 0.8762 - val_shared_Ratelayers_acc_4: 0.7214
# Epoch 39/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.7043 - shared_Ratelayers_loss: 0.3056 - shared_Ratelayers_acc: 0.9550 - shared_Ratelayers_acc_1: 0.9930 - shared_Ratelayers_acc_2: 0.9759 - shared_Ratelayers_acc_3: 0.8890 - shared_Ratelayers_acc_4: 0.8455 - val_loss: 0.9728 - val_shared_Ratelayers_loss: 0.3809 - val_shared_Ratelayers_acc: 0.9102 - val_shared_Ratelayers_acc_1: 0.9536 - val_shared_Ratelayers_acc_2: 0.9505 - val_shared_Ratelayers_acc_3: 0.9102 - val_shared_Ratelayers_acc_4: 0.8854
# Epoch 40/100
# 1288/1288 [==============================] - 74s 57ms/step - loss: 0.6269 - shared_Ratelayers_loss: 0.2660 - shared_Ratelayers_acc: 0.9612 - shared_Ratelayers_acc_1: 0.9961 - shared_Ratelayers_acc_2: 0.9736 - shared_Ratelayers_acc_3: 0.9053 - shared_Ratelayers_acc_4: 0.8665 - val_loss: 2.1753 - val_shared_Ratelayers_loss: 1.1207 - val_shared_Ratelayers_acc: 0.8204 - val_shared_Ratelayers_acc_1: 0.9659 - val_shared_Ratelayers_acc_2: 0.9505 - val_shared_Ratelayers_acc_3: 0.7957 - val_shared_Ratelayers_acc_4: 0.6316
# Epoch 41/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.6126 - shared_Ratelayers_loss: 0.2546 - shared_Ratelayers_acc: 0.9581 - shared_Ratelayers_acc_1: 0.9953 - shared_Ratelayers_acc_2: 0.9806 - shared_Ratelayers_acc_3: 0.8960 - shared_Ratelayers_acc_4: 0.8797 - val_loss: 2.1856 - val_shared_Ratelayers_loss: 1.3598 - val_shared_Ratelayers_acc: 0.8421 - val_shared_Ratelayers_acc_1: 0.9536 - val_shared_Ratelayers_acc_2: 0.9381 - val_shared_Ratelayers_acc_3: 0.9505 - val_shared_Ratelayers_acc_4: 0.5728
# Epoch 42/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.5777 - shared_Ratelayers_loss: 0.2427 - shared_Ratelayers_acc: 0.9682 - shared_Ratelayers_acc_1: 0.9984 - shared_Ratelayers_acc_2: 0.9759 - shared_Ratelayers_acc_3: 0.9107 - shared_Ratelayers_acc_4: 0.8913 - val_loss: 1.3751 - val_shared_Ratelayers_loss: 0.7651 - val_shared_Ratelayers_acc: 0.9164 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9536 - val_shared_Ratelayers_acc_3: 0.9412 - val_shared_Ratelayers_acc_4: 0.6811
# Epoch 43/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.5396 - shared_Ratelayers_loss: 0.2241 - shared_Ratelayers_acc: 0.9752 - shared_Ratelayers_acc_1: 0.9969 - shared_Ratelayers_acc_2: 0.9744 - shared_Ratelayers_acc_3: 0.9200 - shared_Ratelayers_acc_4: 0.9068 - val_loss: 1.2188 - val_shared_Ratelayers_loss: 0.6456 - val_shared_Ratelayers_acc: 0.9350 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.9598 - val_shared_Ratelayers_acc_3: 0.9567 - val_shared_Ratelayers_acc_4: 0.7554
# Epoch 44/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.5340 - shared_Ratelayers_loss: 0.2210 - shared_Ratelayers_acc: 0.9705 - shared_Ratelayers_acc_1: 0.9953 - shared_Ratelayers_acc_2: 0.9752 - shared_Ratelayers_acc_3: 0.9239 - shared_Ratelayers_acc_4: 0.9045 - val_loss: 2.3515 - val_shared_Ratelayers_loss: 1.0585 - val_shared_Ratelayers_acc: 0.8576 - val_shared_Ratelayers_acc_1: 0.9690 - val_shared_Ratelayers_acc_2: 0.8359 - val_shared_Ratelayers_acc_3: 0.7337 - val_shared_Ratelayers_acc_4: 0.6966
# Epoch 45/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.5053 - shared_Ratelayers_loss: 0.2013 - shared_Ratelayers_acc: 0.9689 - shared_Ratelayers_acc_1: 0.9946 - shared_Ratelayers_acc_2: 0.9767 - shared_Ratelayers_acc_3: 0.9309 - shared_Ratelayers_acc_4: 0.9208 - val_loss: 3.6077 - val_shared_Ratelayers_loss: 1.9949 - val_shared_Ratelayers_acc: 0.8545 - val_shared_Ratelayers_acc_1: 0.9133 - val_shared_Ratelayers_acc_2: 0.8669 - val_shared_Ratelayers_acc_3: 0.7585 - val_shared_Ratelayers_acc_4: 0.3963
# Epoch 46/100
# 1288/1288 [==============================] - 74s 58ms/step - loss: 0.4730 - shared_Ratelayers_loss: 0.1896 - shared_Ratelayers_acc: 0.9837 - shared_Ratelayers_acc_1: 0.9977 - shared_Ratelayers_acc_2: 0.9705 - shared_Ratelayers_acc_3: 0.9262 - shared_Ratelayers_acc_4: 0.9293 - val_loss: 2.8957 - val_shared_Ratelayers_loss: 1.5126 - val_shared_Ratelayers_acc: 0.8700 - val_shared_Ratelayers_acc_1: 0.9474 - val_shared_Ratelayers_acc_2: 0.9102 - val_shared_Ratelayers_acc_3: 0.5697 - val_shared_Ratelayers_acc_4: 0.4706
# Epoch 47/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.4080 - shared_Ratelayers_loss: 0.1630 - shared_Ratelayers_acc: 0.9806 - shared_Ratelayers_acc_1: 0.9961 - shared_Ratelayers_acc_2: 0.9798 - shared_Ratelayers_acc_3: 0.9526 - shared_Ratelayers_acc_4: 0.9363 - val_loss: 3.1528 - val_shared_Ratelayers_loss: 1.8578 - val_shared_Ratelayers_acc: 0.8297 - val_shared_Ratelayers_acc_1: 0.9443 - val_shared_Ratelayers_acc_2: 0.9257 - val_shared_Ratelayers_acc_3: 0.8328 - val_shared_Ratelayers_acc_4: 0.6409
# Epoch 48/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.4130 - shared_Ratelayers_loss: 0.1643 - shared_Ratelayers_acc: 0.9767 - shared_Ratelayers_acc_1: 0.9961 - shared_Ratelayers_acc_2: 0.9752 - shared_Ratelayers_acc_3: 0.9503 - shared_Ratelayers_acc_4: 0.9379 - val_loss: 2.9408 - val_shared_Ratelayers_loss: 1.6906 - val_shared_Ratelayers_acc: 0.8359 - val_shared_Ratelayers_acc_1: 0.9319 - val_shared_Ratelayers_acc_2: 0.7709 - val_shared_Ratelayers_acc_3: 0.9102 - val_shared_Ratelayers_acc_4: 0.4118
# Epoch 49/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.4010 - shared_Ratelayers_loss: 0.1554 - shared_Ratelayers_acc: 0.9744 - shared_Ratelayers_acc_1: 0.9984 - shared_Ratelayers_acc_2: 0.9806 - shared_Ratelayers_acc_3: 0.9449 - shared_Ratelayers_acc_4: 0.9363 - val_loss: 2.6712 - val_shared_Ratelayers_loss: 1.3304 - val_shared_Ratelayers_acc: 0.8328 - val_shared_Ratelayers_acc_1: 0.9350 - val_shared_Ratelayers_acc_2: 0.8885 - val_shared_Ratelayers_acc_3: 0.6904 - val_shared_Ratelayers_acc_4: 0.6440
# Epoch 50/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.3859 - shared_Ratelayers_loss: 0.1498 - shared_Ratelayers_acc: 0.9837 - shared_Ratelayers_acc_1: 0.9961 - shared_Ratelayers_acc_2: 0.9814 - shared_Ratelayers_acc_3: 0.9425 - shared_Ratelayers_acc_4: 0.9449 - val_loss: 2.8404 - val_shared_Ratelayers_loss: 1.3132 - val_shared_Ratelayers_acc: 0.8173 - val_shared_Ratelayers_acc_1: 0.9443 - val_shared_Ratelayers_acc_2: 0.8731 - val_shared_Ratelayers_acc_3: 0.7461 - val_shared_Ratelayers_acc_4: 0.6842
# Epoch 51/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.2761 - shared_Ratelayers_loss: 0.0989 - shared_Ratelayers_acc: 0.9884 - shared_Ratelayers_acc_1: 1.0000 - shared_Ratelayers_acc_2: 0.9806 - shared_Ratelayers_acc_3: 0.9581 - shared_Ratelayers_acc_4: 0.9651 - val_loss: 2.5990 - val_shared_Ratelayers_loss: 0.8233 - val_shared_Ratelayers_acc: 0.8978 - val_shared_Ratelayers_acc_1: 0.9536 - val_shared_Ratelayers_acc_2: 0.9071 - val_shared_Ratelayers_acc_3: 0.5139 - val_shared_Ratelayers_acc_4: 0.6471
# Epoch 52/100
# 1288/1288 [==============================] - 76s 59ms/step - loss: 0.3387 - shared_Ratelayers_loss: 0.1355 - shared_Ratelayers_acc: 0.9829 - shared_Ratelayers_acc_1: 0.9946 - shared_Ratelayers_acc_2: 0.9837 - shared_Ratelayers_acc_3: 0.9550 - shared_Ratelayers_acc_4: 0.9464 - val_loss: 2.1556 - val_shared_Ratelayers_loss: 1.0397 - val_shared_Ratelayers_acc: 0.8421 - val_shared_Ratelayers_acc_1: 0.9505 - val_shared_Ratelayers_acc_2: 0.9226 - val_shared_Ratelayers_acc_3: 0.8607 - val_shared_Ratelayers_acc_4: 0.7245
# Epoch 53/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.3047 - shared_Ratelayers_loss: 0.1165 - shared_Ratelayers_acc: 0.9876 - shared_Ratelayers_acc_1: 0.9984 - shared_Ratelayers_acc_2: 0.9790 - shared_Ratelayers_acc_3: 0.9635 - shared_Ratelayers_acc_4: 0.9542 - val_loss: 3.1464 - val_shared_Ratelayers_loss: 1.6109 - val_shared_Ratelayers_acc: 0.8359 - val_shared_Ratelayers_acc_1: 0.9505 - val_shared_Ratelayers_acc_2: 0.8978 - val_shared_Ratelayers_acc_3: 0.7090 - val_shared_Ratelayers_acc_4: 0.5170
# Epoch 54/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.2297 - shared_Ratelayers_loss: 0.0875 - shared_Ratelayers_acc: 0.9884 - shared_Ratelayers_acc_1: 0.9961 - shared_Ratelayers_acc_2: 0.9860 - shared_Ratelayers_acc_3: 0.9713 - shared_Ratelayers_acc_4: 0.9713 - val_loss: 2.1951 - val_shared_Ratelayers_loss: 1.0821 - val_shared_Ratelayers_acc: 0.8854 - val_shared_Ratelayers_acc_1: 0.9598 - val_shared_Ratelayers_acc_2: 0.9040 - val_shared_Ratelayers_acc_3: 0.9226 - val_shared_Ratelayers_acc_4: 0.7430
# Epoch 55/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.3231 - shared_Ratelayers_loss: 0.1150 - shared_Ratelayers_acc: 0.9798 - shared_Ratelayers_acc_1: 0.9984 - shared_Ratelayers_acc_2: 0.9783 - shared_Ratelayers_acc_3: 0.9557 - shared_Ratelayers_acc_4: 0.9565 - val_loss: 3.0209 - val_shared_Ratelayers_loss: 1.7150 - val_shared_Ratelayers_acc: 0.8359 - val_shared_Ratelayers_acc_1: 0.9598 - val_shared_Ratelayers_acc_2: 0.8700 - val_shared_Ratelayers_acc_3: 0.8885 - val_shared_Ratelayers_acc_4: 0.6440
# Epoch 56/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.2709 - shared_Ratelayers_loss: 0.1023 - shared_Ratelayers_acc: 0.9876 - shared_Ratelayers_acc_1: 0.9977 - shared_Ratelayers_acc_2: 0.9837 - shared_Ratelayers_acc_3: 0.9627 - shared_Ratelayers_acc_4: 0.9651 - val_loss: 2.1274 - val_shared_Ratelayers_loss: 0.9367 - val_shared_Ratelayers_acc: 0.8854 - val_shared_Ratelayers_acc_1: 0.9598 - val_shared_Ratelayers_acc_2: 0.8731 - val_shared_Ratelayers_acc_3: 0.8638 - val_shared_Ratelayers_acc_4: 0.7833
# Epoch 57/100
# 1288/1288 [==============================] - 74s 58ms/step - loss: 0.3104 - shared_Ratelayers_loss: 0.1278 - shared_Ratelayers_acc: 0.9829 - shared_Ratelayers_acc_1: 0.9946 - shared_Ratelayers_acc_2: 0.9798 - shared_Ratelayers_acc_3: 0.9697 - shared_Ratelayers_acc_4: 0.9495 - val_loss: 2.4517 - val_shared_Ratelayers_loss: 1.1531 - val_shared_Ratelayers_acc: 0.8762 - val_shared_Ratelayers_acc_1: 0.9474 - val_shared_Ratelayers_acc_2: 0.8328 - val_shared_Ratelayers_acc_3: 0.9381 - val_shared_Ratelayers_acc_4: 0.7090
# Epoch 58/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.2149 - shared_Ratelayers_loss: 0.0617 - shared_Ratelayers_acc: 0.9922 - shared_Ratelayers_acc_1: 0.9977 - shared_Ratelayers_acc_2: 0.9829 - shared_Ratelayers_acc_3: 0.9697 - shared_Ratelayers_acc_4: 0.9790 - val_loss: 2.2808 - val_shared_Ratelayers_loss: 1.0174 - val_shared_Ratelayers_acc: 0.8731 - val_shared_Ratelayers_acc_1: 0.9628 - val_shared_Ratelayers_acc_2: 0.8266 - val_shared_Ratelayers_acc_3: 0.9350 - val_shared_Ratelayers_acc_4: 0.7183
# Epoch 59/100
# 1288/1288 [==============================] - 75s 58ms/step - loss: 0.2788 - shared_Ratelayers_loss: 0.1029 - shared_Ratelayers_acc: 0.9891 - shared_Ratelayers_acc_1: 0.9946 - shared_Ratelayers_acc_2: 0.9806 - shared_Ratelayers_acc_3: 0.9635 - shared_Ratelayers_acc_4: 0.9612 - val_loss: 3.0351 - val_shared_Ratelayers_loss: 1.3377 - val_shared_Ratelayers_acc: 0.8793 - val_shared_Ratelayers_acc_1: 0.9721 - val_shared_Ratelayers_acc_2: 0.8978 - val_shared_Ratelayers_acc_3: 0.7430 - val_shared_Ratelayers_acc_4: 0.6780
# Epoch 00059: early stopping
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-05fa85389b53> in <module>
#       4 # テスト
#       5 #score = model.evaluate(test_learn, test_label, batch_size = batch_size, verbose = 1)
# ----> 6 print("score:", score)
#
# NameError: name 'score' is not defined

# %%
def freeze_layers(model):
    for i in model.layers:
        i.trainable = False
        if isinstance(i, Model):
            freeze_layers(i)
    return model

model_freezed = freeze_layers(model)
model_freezed.save('model/file0212-2.tf')

# %%
def plot_history_loss(hist):
    # 損失値(Loss)の遷移のプロット
    plt.plot(hist.history['loss'],label="loss for training")
    plt.plot(hist.history['val_loss'],label="loss for validation")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='best')
    plt.show()

def plot_history_acc(hist):
    # 精度(Accuracy)の遷移のプロット
    plt.plot(hist.history['acc'],label="loss for training")
    plt.plot(hist.history['val_acc'],label="loss for validation")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc='best')
    plt.ylim([0, 1])
    plt.show()

plot_history_loss(hist)
plot_history_acc(hist)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-41b18e356786> in <module>
#      21
#      22 plot_history_loss(hist)
# ---> 23 plot_history_acc(hist)
#
# <ipython-input-27-41b18e356786> in plot_history_acc(hist)
#      11 def plot_history_acc(hist):
#      12     # 精度(Accuracy)の遷移のプロット
# ---> 13     plt.plot(hist.history['acc'],label="loss for training")
#      14     plt.plot(hist.history['val_acc'],label="loss for validation")
#      15     plt.title('model accuracy')
#
# KeyError: 'acc'

# %%
# カメラ番号をランダムに並び替えることでデータの偏りをなくそうというデータ作成プログラム


# def make_learndata(self):
#         data_name=self.file_name+"learn_0_"+str(rate)+".npy"
#         if (os.path.isfile(data_name)):
#             test=np.load(data_name)
#         else:
#             all_list = [np.empty((0,self.timesteps, self.width, self.height, 3), np.float)]*self.camera_num
#             tmp_list = [np.empty((0,self.timesteps, self.width, self.height, 3), np.float)]*self.camera_num
#             for i in range(0, self.labelData.shape[0]):
#                 #まずはすべての分だけ回す
#                 pro_size=20
#                 bar = int(i*pro_size/self.labelData.shape[0])
#                 pro_bar = ('=' * bar) + (' ' * (pro_size - bar))
#                 percent ='{:03f}'.format(i / self.labelData.shape[0] * 100.)
#                 print('\r [{0}] {1}%'.format(pro_bar, percent), end='')
                            
#                 for j in range(0,self.camera_num):
#                     for camera in range(0, self.camera_num):
#                         #カメラの台数だけ回す
#                         #tmp_list[camera]の同じ引数（番号）には角度を同じ分だけずらした同じ時間軸のsequenceが入っている．
#                         first_list =np.empty((0, self.width, self.height, 3), np.float)
#                         for l in range(0, self.timesteps):
#                             #timesteps分のndarrayを作る．
#                             img=self.learnData[camera,i+l]
#                             first_list =np.append(first_list, [img], axis=0)
#                         #あるカメラについて，１つのsequenceがfirst_listに出来上がっている状態．
#                         tmp_camera_num=self.camera_return(camera+j)
#                         tmp_list[tmp_camera_num]=np.append(tmp_list[tmp_camera_num], [first_list], axis=0)
    

#                 if(tmp_list[0].shape[0]>100 or i == self.labelData.shape[0]-1):
#                     #処理時間短縮のため，sequenceがtmp_listに溜まってきたら，全体に統合してまたtmp_listを初期化する．
#                     for camera in range(0, self.camera_num):
#                         all_list[camera]=np.append(all_list[camera], tmp_list[camera], axis=0)
#                         tmp_list[camera] = np.empty((0,self.timesteps, self.width, self.height, 3), np.float)
            
#             for camera in range(0, self.camera_num):
#                 print(all_list[camera].shape)
#                 data_name=self.file_name+"learn_"+str(camera)+"_"+str(rate)
#                 np.save(data_name, all_list[camera])
    
    
#     def make_labeldata(self):
#         data_name=self.file_name+"final_label_"+str(rate)+"_.npy"
#         if (os.path.isfile(data_name)):
#             test=np.load(data_name)
#         else:
#             test = np.empty((0,self.camera_num), np.float)
#             for i in range(0,self.labelData.shape[0]):
#                 for j in range(0, self.camera_num):
#                     tmp=self.camera_return(np.argmax(self.labelData[i])+j)
#                     a_one_hot = np.identity(self.camera_num)[tmp]
#                     print(a_one_hot)
#                     test = np.append(test, [a_one_hot], axis=0)
#             print(test.shape)
#             np.save(data_name, test)


    
#     def camera_return(self, num=0):
#         if(num<self.camera_num):
#             return num
#         else:
#             return num-self.camera_num
